# %% [markdown]
# ### Case Study 3: Fuel Efficiency Versus Speed
#
# **Objective:** Calculate the fuel efficiency in miles per gallon (MPG) or Liters per 100 km (L/100 km). Use regression to develop a model of how measured factors relate to the fuel efficiency.
#
# Machine Learning for Engineers: [Automotive Monitoring](https://www.apmonitor.com/pds/index.php/Main/AutomotiveMonitoring)
# - Description: Machine learning project with automotive data. Data includes travel distance, time, fuel rate, air flow, oxygen ratio, and other parameters available from an OBD2 interface.
# - [Course Overview](https://apmonitor.com/pds)
# - [Course Schedule](https://apmonitor.com/pds/index.php/Main/CourseSchedule)
#
# <img width=400px align=left src='https://apmonitor.com/pds/uploads/Main/automotive_monitoring.png'>

# %%
import seaborn as sns
import xgboost as xgb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from keras.layers import Dense
from keras.models import Sequential
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_absolute_percentage_error as MAPE
from sklearn.metrics import r2_score as r2
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import MinMaxScaler as mms
from tqdm.keras import TqdmCallback
import keras

# %% [markdown]
# ### Import Data and Display Column names

# %%
url = '/content/automotive.txt'
data = pd.read_csv(url)
data.rename(columns={'Calculated instant fuel consumption (MPG)':"MPG"},inplace=True)
data.columns
# Out:
# Index(['time', 'Average fuel consumption (MPG)',
#        'Average fuel consumption (total) (MPG)',
#        'Average fuel consumption 10 sec (MPG)', 'Average speed (mph)', 'MPG',
#        'Calculated instant fuel rate (gal./h)', 'Distance travelled (miles)',
#        'Distance travelled (total) (miles)', 'Engine RPM (rpm)',
#        'Fuel economizer (based on fuel system status and throttle position) ()',
#        'Fuel used (gallon)', 'Fuel used (total) (gallon)',
#        'Fuel used price ($)', 'Fuel used price (total) ($)',
#        'Instant engine power (based on fuel consumption) (hp)',
#        'MAF air flow rate (g/sec)',
#        'Oxygen sensor 1 Wide Range Current (mA) (mA)',
#        'Oxygen sensor 1 Wide Range Equivalence ratio ()',
#        'Throttle position (%)', 'Vehicle acceleration (g)',
#        'Vehicle speed (mph)', 'Unnamed: 22'],
#       dtype='object')

# %% [markdown]
# ### Reformat Time

# %%
from datetime import datetime
dtobj = datetime.strptime(data['time'].iloc[0],'%I:%M:%S.%f')
dtobj2 = datetime.strptime(data['time'].iloc[-1],'%I:%M:%S.%f')
dataf = data.copy()
dataf['time'] = data['time'].apply(func=lambda x: datetime.strptime(x,'%I:%M:%S.%f'))
dataf['timetot'] = dataf['time'].apply(lambda x:(x-dtobj).microseconds/10**6+(x-dtobj).seconds)
dataf['timetot'].sample(5)
# Out:
# 27148    5164.714
# 6708     1079.567
# 21280    3916.725
# 17477    2830.680
# 35561    6541.721
# Name: timetot, dtype: float64

# %% [markdown]
# ### Plot and Visualize the Data

# %%
label = 'MPG'
#predict MPG from RPM, and speed
sns.violinplot(data=dataf[label])
plt.xlabel(label)
plt.show()
dataf.boxplot('Vehicle speed (mph)')
plt.show()
dataf.boxplot('Engine RPM (rpm)')
plt.show()

# %% [markdown]
# ## Reformat Data
# Use Vehicle Speed, Acceleration, and RPM as features. Visualize the effects of well-known aspects of driving on fuel efficiency.

# %%
rpm = 'Engine RPM (rpm)'
speed = 'Vehicle speed (mph)'
speeds = dataf[speed].dropna()
acel = 'Vehicle acceleration (g)'
gal = 'Fuel used (gallon)'
alls = [acel,speed,rpm,label]
dataf[alls].isna().sum()
datan = dataf[alls].copy().fillna(method='ffill').drop_duplicates()
datan = datan[datan[label]>0]
datan = datan[datan[label]<45] #Anything higher than this is most likely coasting
datan.sample(20)
# Out:
# /tmp/ipykernel_2760/972278211.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   datan = dataf[alls].copy().fillna(method='ffill').drop_duplicates()
#        Vehicle acceleration (g)  Vehicle speed (mph)  Engine RPM (rpm)  \
# 27702                  0.017017            77.050028            3286.0
# 27216                  0.009094            68.350831            2928.0
# 29835                 -0.212909             8.699197             746.0
# 2051                   0.070205            22.369363            1758.0
# 28254                  0.036430            75.185914            3214.0
# 26545                  0.037949            61.515748            2660.0
# 38297                 -0.018082             4.970970             760.0
# 27138                  0.017927            69.593574            2986.0
# 15282                  0.008887            72.079058            3118.0
# 8732                   0.017814            77.671399            3328.0
# 35833                  0.009031             3.728227             786.0
# 6949                  -0.027106            15.534280            1639.0
# 3677                   0.113838            15.534280            1885.0
# 12012                 -0.018087            77.050028            3317.0
# 7973                   0.083959            42.253241            2256.0
# 45609                  0.059878            32.311302            1811.0
# 48326                  0.126237             8.699197            1368.0
# 17064                  0.110323            42.874612            2258.0
# 47437                  0.132279            22.990734            1882.0
# 35506                  0.008660            34.796787            1529.0
#
#              MPG
# 27702  33.552447
# 27216  25.688182
# 29835  40.470528
# 2051   13.845448
# 28254  29.321114
# 26545  44.667416
# 38297  23.930446
# 27138  20.464892
# 15282  38.950301
# 8732   30.686229
# 35833  15.416208
# 6949   11.805708
# 3677    9.994670
# 12012  33.607337
# 7973   14.555664
# 45609  14.272288
# 48326   5.579921
# 17064  17.278157
# 47437  12.718937
# 35506  25.628750

# %% [markdown]
# ### Show Heatmap

# %%
sns.heatmap(dataf.copy().fillna(method='ffill').drop_duplicates().corr(),annot=False,fmt='f')

plt.show()
# Out:
# /tmp/ipykernel_2760/2199664378.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   sns.heatmap(dataf.copy().fillna(method='ffill').drop_duplicates().corr(),annot=False,fmt='f')

# %% [markdown]
# ### Create Pairplot

# %%
sns.pairplot(datan)
plt.show()

# %% [markdown]
# ### Scale Data, Train model, and show accuracy

# %%
s = mms()

use = alls.copy()
use.remove('MPG')

dataS = pd.DataFrame(np.sqrt(np.array(s.fit_transform(datan))), columns =alls)
Xtrain, Xtest, ytrain, ytest = tts(dataS[use], dataS[label], test_size = .2, random_state = 87)

model = xgb.XGBRegressor()

m = model.fit(dataS[use], dataS[label])

datatest = Xtest.join(ytest,how='right')
yp = m.predict(datatest[use])
unscaled = pd.DataFrame(s.inverse_transform((datatest.values)**2),columns = alls)
datap = datatest.copy()
datap[label] = yp
unscaledy = unscaled[label]
unscaledp = pd.DataFrame(s.inverse_transform(datap.values**2),columns=alls)[label]
perc = MAPE(unscaledy, unscaledp)

scoree = MAE(unscaledy, unscaledp)
scorer = r2(unscaledy, unscaledp)
plt.plot(unscaledy, unscaledp, 'bo')
plt.text(50,50,f'R2={round(scorer,3)}\nMAPE={round(perc,3)}\nMAE={round(scoree,3)}')
plt.xlabel('True')
plt.ylabel('Predicted')
plt.title('XGB Regressor')
print(f'{perc:.4g}',f'{scoree:.4g}, r2={scorer}')
# linear model
reg = LinearRegression().fit(dataS[use], dataS[label])
ypr = reg.predict(datatest[use])
r2lin = r2(datatest[label],ypr)
# Out:
# 0.1466 2.872, r2=0.8882810234460026

# %% [markdown]
# ### Create a Neural Network to compare performance with XGBoost Regression

# %%
mod = Sequential()
mod.add(Dense(3,input_shape=(Xtrain.shape[1],),activation='relu'))
mod.add(Dense(1,activation='linear'))
mod.summary()
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 3)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16 (64.00 B)
#  Trainable params: 16 (64.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
mod.compile(optimizer='sgd', loss='mse')
history = mod.fit(Xtrain,ytrain,epochs = 350, verbose=True, \
                  validation_data=(Xtest,ytest),\
                  callbacks=[TqdmCallback(verbose=1), \
                             EarlyStopping(monitor = 'loss',patience=4)])
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# Epoch 1/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1153 - val_loss: 0.0325
# Epoch 2/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0318 - val_loss: 0.0305
# Epoch 3/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0298 - val_loss: 0.0283
# Epoch 4/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0280 - val_loss: 0.0267
# Epoch 5/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0265 - val_loss: 0.0253
# Epoch 6/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0253 - val_loss: 0.0243
# Epoch 7/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0243 - val_loss: 0.0233
# Epoch 8/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0235 - val_loss: 0.0226
# Epoch 9/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0228 - val_loss: 0.0221
# Epoch 10/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0223 - val_loss: 0.0217
# Epoch 11/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 12/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0214 - val_loss: 0.0207
# Epoch 13/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0208 - val_loss: 0.0202
# Epoch 14/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0199 - val_loss: 0.0189
# Epoch 15/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0191 - val_loss: 0.0186
# Epoch 16/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0189 - val_loss: 0.0184
# Epoch 17/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0187 - val_loss: 0.0183
# Epoch 18/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0186 - val_loss: 0.0181
# Epoch 19/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0185 - val_loss: 0.0179
# Epoch 20/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0183 - val_loss: 0.0178
# Epoch 21/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0182 - val_loss: 0.0177
# Epoch 22/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - val_loss: 0.0176
# Epoch 23/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - val_loss: 0.0175
# Epoch 24/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0179 - val_loss: 0.0174
# Epoch 25/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0178 - val_loss: 0.0174
# Epoch 26/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0177 - val_loss: 0.0172
# Epoch 27/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0172
# Epoch 28/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0171
# Epoch 29/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0171
# Epoch 30/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0170
# Epoch 31/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174 - val_loss: 0.0170
# Epoch 32/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - val_loss: 0.0169
# Epoch 33/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - val_loss: 0.0170
# Epoch 34/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0172 - val_loss: 0.0168
# Epoch 35/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0172 - val_loss: 0.0167
# Epoch 36/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0172 - val_loss: 0.0167
# Epoch 37/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0171 - val_loss: 0.0167
# Epoch 38/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0171 - val_loss: 0.0167
# Epoch 39/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0170 - val_loss: 0.0166
# Epoch 40/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0170 - val_loss: 0.0166
# Epoch 41/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170 - val_loss: 0.0166
# Epoch 42/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170 - val_loss: 0.0165
# Epoch 43/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - val_loss: 0.0164
# Epoch 44/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - val_loss: 0.0164
# Epoch 45/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - val_loss: 0.0166
# Epoch 46/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0169 - val_loss: 0.0164
# Epoch 47/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - val_loss: 0.0164
# Epoch 48/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0169 - val_loss: 0.0164
# Epoch 49/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - val_loss: 0.0163
# Epoch 50/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0168 - val_loss: 0.0163
# Epoch 51/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - val_loss: 0.0164
# Epoch 52/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0168 - val_loss: 0.0163
# Epoch 53/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - val_loss: 0.0163
# Epoch 54/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0168 - val_loss: 0.0163
# Epoch 55/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0168 - val_loss: 0.0162
# Epoch 56/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0168 - val_loss: 0.0162
# Epoch 57/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - val_loss: 0.0163
# Epoch 58/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0167 - val_loss: 0.0164
# Epoch 59/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 60/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 61/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 62/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 63/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 64/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 65/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 66/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0164
# Epoch 67/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 68/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 69/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 70/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 71/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 72/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 73/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 74/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 75/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 76/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 77/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166 - val_loss: 0.0161
# Epoch 78/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0166 - val_loss: 0.0161
# Epoch 79/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 80/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166 - val_loss: 0.0161
# Epoch 81/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 82/350
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0167 - val_loss: 0.0161

# %% [markdown]
# ### Plot Learning History

# %%
plt.semilogy(history.history['loss'],label='loss')
plt.semilogy(history.history['val_loss'],label='val_loss')
plt.legend()
plt.show()
mod.save('Model_3var.keras')

# %%
mod = keras.models.load_model('Model_3var.keras')
yp = mod.predict(datatest[use])
unscaled = pd.DataFrame(s.inverse_transform(datatest),columns = alls)
datap = datatest.copy()
datap[label] = yp
unscaledy = unscaled[label]
unscaledp = pd.DataFrame(s.inverse_transform(datap),columns=alls)[label]
perc = MAPE(unscaledy, unscaledp)

scoree = MAE(unscaledy, unscaledp)
scorer = r2(unscaledy, unscaledp)
plt.plot(unscaledy, unscaledp, 'bo')
plt.xlabel('True')
print(f'{perc:.4g}',f'{scoree:.4g}, r2={scorer}')
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 6 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 0.174 4.489, r2=0.6397879842432361

# %% [markdown]
# ### View Predictions

# %%
# XGB Regression
rpmmed = np.ones(datan.shape[0])*dataS[rpm].median()
speedmed = np.ones(datan.shape[0])*dataS[speed].median()
acelmed = np.ones(datan.shape[0])*dataS[acel].median()
print('RPM,Speed,Acceleration median values')
print(dataS[rpm].median(),dataS[speed].median(),dataS[acel].median())
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
sns.kdeplot(dataS[rpm])
plt.subplot(1,3,2)
sns.kdeplot(dataS[speed])
plt.subplot(1,3,3)
sns.kdeplot(dataS[acel])
plt.show()
# Out:
# RPM,Speed,Acceleration median values
# 0.744363176884441 0.6747028090922809 0.8112128339807488

# %% [markdown]
# ## Display Extrapolations with one variable

# %%
# Use the XGBoost model since it performed better
n = datan.shape[0]
rpmvar = np.linspace(.5,1,n)
speedvar = np.linspace(0,1,n)
acelvar = np.linspace(.3,1,n)
rpmdf = pd.DataFrame(np.array([acelmed,speedmed,rpmvar]).T,columns=use)
speeddf = pd.DataFrame(np.array([acelmed,speedvar,rpmmed]).T,columns=use)
aceldf = pd.DataFrame(np.array([acelvar,speedmed,rpmmed]).T,columns=use)
rpmpred = m.predict(rpmdf)
speedpred = m.predict(speeddf)
acelpred = m.predict(aceldf)
trrpm = pd.DataFrame(s.inverse_transform(rpmdf.join(pd.DataFrame(rpmpred))),columns = use+[label])
trspeed = pd.DataFrame(s.inverse_transform(speeddf.join(pd.DataFrame(speedpred))),columns = use+[label])
tracel = pd.DataFrame(s.inverse_transform(aceldf.join(pd.DataFrame(acelpred))),columns = use+[label])

plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
plt.plot(trrpm[rpm],trrpm[label])
plt.ylabel('MPG'); plt.xlabel('RPM')
plt.subplot(1,3,2)
plt.plot(trspeed[speed],trspeed[label])
plt.ylabel('MPG'); plt.xlabel('Speed (mi/hr)')
plt.subplot(1,3,3)
plt.plot(tracel[acel],tracel[label])
#tracel.plot(x=acel,y=label)
plt.ylabel('MPG'); plt.xlabel('Acceleration')
plt.show()

# %% [markdown]
# ### Discussion
#
# The three cross sections show the MPG varying a single variable while the other variables are held constant at a median value. This method inherently misses important behavior because the other values are restricted to the median. However, the trends are visible and most likely carry throughout portions of the 4-d model, even if the actual magnitudes vary. Some observations:
#
# - The highest MPG (fuel efficiency) is at lower RPM for the engine. The data where the car is coasting may influence this higher trend at lower RPM.
# - The highest MPG is at the highest speed with highway driving. City driving fuel efficiency is lower due to braking action and lower average velocity.
# - Fuel efficiency decreases with higher acceleration.

# %% [markdown]
# ### 4D Figure with 3D + Color

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
datass = dataS.copy()
datass[label] = m.predict(dataS[use])
datainv = pd.DataFrame(s.inverse_transform(datass),columns = use+[label])
img = ax.scatter(datainv[rpm],datainv[speed],datainv[acel],c=datainv[label],cmap = plt.hot())
fig.colorbar(img)
plt.xlabel('RPM')
plt.ylabel('Speed')
ax.set_zlabel('Acceleration')
ax.view_init(azim=34,elev = -51)
plt.show()
